# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Parameter selection, Validation & Testing

# %% [markdown]
# Most models have parameters that influence how complex a model they can learn. Remember using KNeighborsRegressor.
# If we change the number of neighbors we consider, we get a smoother and smoother prediction:

# %%
from utils import plot_kneighbors_regularization
plot_kneighbors_regularization()

# %% [markdown]
# In the above figure, we see fits for three different values of ``n_neighbors``.
# For ``n_neighbors=2``, the data is overfit, the model is too flexible and can adjust too much to the noise in the training data. For ``n_neighbors=20``, the model is not flexible enough, and can not model the variation in the data appropriately.
#
# In the middle, for ``n_neighbors = 5``, we have found a good mid-point. It fits
# the data fairly well, and does not suffer from the overfit or underfit
# problems seen in the figures on either side. What we would like is a
# way to quantitatively identify overfit and underfit, and optimize the
# hyperparameters (in this case, the polynomial degree d) in order to
# determine the best algorithm.

# %% [markdown]
# We trade off remembering too much about the particularities and noise of the training data vs. not modeling enough of the variability.
#
# This is a **trade-off** that needs to be made in basically every machine learning application and is a central concept, called **bias-variance-tradeoff** or _"overfitting vs underfitting"_.

# %% [markdown]
# <img src="images/overfitting_underfitting_cartoon.svg" width="50%">

# %% [markdown]
# ## Hyperparameters, Over-fitting, and Under-fitting
# Unfortunately, there is no general rule how to find the sweet spot, and so machine learning practitioners have to find the best trade-off of model-complexity and generalization by trying several parameter settings.
# Most commonly this is done using a brute force search, for example over multiple values of ``n_neighbors``:

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.neighbors import KNeighborsRegressor

# generate toy dataset:
x = np.linspace(-3, 3, 100)
rng = np.random.RandomState(42)
y = np.sin(4 * x) + x + rng.normal(size=len(x))
X = x[:, np.newaxis]

# %%
cv = KFold(n_splits=5, shuffle=True)

# for each parameter setting do cross_validation:
for n_neighbors in [1, 3, 5, 10, 20]:
    scores = cross_val_score(KNeighborsRegressor(n_neighbors=n_neighbors), X, y, cv=cv)
    print("n_neighbors: %d, average score: %f" % (n_neighbors, np.mean(scores)))
# Out:
# n_neighbors: 1, average score: 0.556570
# n_neighbors: 3, average score: 0.696868
# n_neighbors: 5, average score: 0.726789
# n_neighbors: 10, average score: 0.713956
# n_neighbors: 20, average score: 0.547142

# %% [markdown]
# There is a function in scikit-learn, called ``validation_plot`` to reproduce the cartoon figure above. It plots one parameter, such as the number of neighbors, against training and validation error (using cross-validation):

# %%
from sklearn.model_selection import validation_curve
n_neighbors = [1, 3, 5, 10, 20, 50]
train_errors, test_errors = validation_curve(KNeighborsRegressor(), X, y, param_name="n_neighbors",
                                             param_range=n_neighbors, cv=cv)
plt.plot(n_neighbors, train_errors.mean(axis=1), label="train error")
plt.plot(n_neighbors, test_errors.mean(axis=1), label="test error")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# Note that many neighbors mean a "smooth" or "simple" model, so the plot is the mirror image of the diagram above.

# %% [markdown]
# If multiple parameters are important, like the parameters ``C`` and ``gamma`` in an ``SVM`` (more about that later), all possible combinations are tried:

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.svm import SVR

# each parameter setting do cross_validation:
for C in [0.001, 0.01, 0.1, 1, 10]:
    for gamma in [0.001, 0.01, 0.1, 1]:
        scores = cross_val_score(SVR(C=C, gamma=gamma), X, y, cv=cv)
        print("C: %f, gamma: %f, average score: %f" % (C, gamma, np.mean(scores)))
# Out:
# C: 0.001000, gamma: 0.001000, average score: -0.067103
# C: 0.001000, gamma: 0.010000, average score: -0.104767
# C: 0.001000, gamma: 0.100000, average score: -0.158415
# C: 0.001000, gamma: 1.000000, average score: -0.055383
# C: 0.010000, gamma: 0.001000, average score: -0.075711
# C: 0.010000, gamma: 0.010000, average score: -0.136598
# C: 0.010000, gamma: 0.100000, average score: 0.078446
# C: 0.010000, gamma: 1.000000, average score: 0.030459
# C: 0.100000, gamma: 0.001000, average score: -0.090332
# C: 0.100000, gamma: 0.010000, average score: 0.123870
# C: 0.100000, gamma: 0.100000, average score: 0.541838
# C: 0.100000, gamma: 1.000000, average score: 0.465357
# C: 1.000000, gamma: 0.001000, average score: 0.187073
# C: 1.000000, gamma: 0.010000, average score: 0.576037
# C: 1.000000, gamma: 0.100000, average score: 0.600762
# C: 1.000000, gamma: 1.000000, average score: 0.694908
# C: 10.000000, gamma: 0.001000, average score: 0.584780
# C: 10.000000, gamma: 0.010000, average score: 0.587895
# C: 10.000000, gamma: 0.100000, average score: 0.675494
# C: 10.000000, gamma: 1.000000, average score: 0.715423

# %% [markdown]
# As this is such a very common pattern, there is a built-in class for this in scikit-learn, ``GridSearchCV``. ``GridSearchCV`` takes a dictionary that describes the parameters that should be tried and a model to train.
#
# The grid of parameters is defined as a dictionary, where the keys are the parameters and the values are the settings to be tested.

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'C': [0.001, 0.01, 0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1, 1]}

grid = GridSearchCV(SVR(), param_grid=param_grid, cv=cv, verbose=3)

# %% [markdown]
# One of the great things about GridSearchCV is that it is a *meta-estimator*. It takes an estimator like SVR above, and creates a new estimator, that behaves exactly the same - in this case, like a regressor.
# So we can call ``fit`` on it, to train it:

# %%
grid.fit(X, y)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV] C=0.001, gamma=0.001 ............................................
# [CV]  C=0.001, gamma=0.001, score=-0.010365645164542858, total=   0.0s
# [CV] C=0.001, gamma=0.001 ............................................
# [CV] . C=0.001, gamma=0.001, score=-0.07935870509160248, total=   0.0s
# [CV] C=0.001, gamma=0.001 ............................................
# [CV] . C=0.001, gamma=0.001, score=-0.05805276012162963, total=   0.0s
# [CV] C=0.001, gamma=0.001 ............................................
# [CV]  C=0.001, gamma=0.001, score=-0.0005388283716543096, total=   0.0s
# [CV] C=0.001, gamma=0.001 ............................................
# [CV]  C=0.001, gamma=0.001, score=-0.0041442662895145865, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV] . C=0.001, gamma=0.01, score=-0.007752726837914502, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV] .. C=0.001, gamma=0.01, score=-0.07699957362464849, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV] .. C=0.001, gamma=0.01, score=-0.05588989683076151, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV] . C=0.001, gamma=0.01, score=0.0020445864747828946, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV]  C=0.001, gamma=0.01, score=-0.0011135455985156195, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] .... C=0.001, gamma=0.1, score=0.00371697058519016, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] ... C=0.001, gamma=0.1, score=-0.06642401672129705, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] ... C=0.001, gamma=0.1, score=-0.04668206082266457, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] .... C=0.001, gamma=0.1, score=0.01326015909328082, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] ... C=0.001, gamma=0.1, score=0.012247758729178493, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] .... C=0.001, gamma=1, score=0.0028410890728215454, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] ..... C=0.001, gamma=1, score=-0.06791460338788391, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] ..... C=0.001, gamma=1, score=-0.04813002703310643, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] ..... C=0.001, gamma=1, score=0.011325420899125471, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] ..... C=0.001, gamma=1, score=0.009419828437862598, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV] . C=0.01, gamma=0.001, score=-0.007496684306959045, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV] .. C=0.01, gamma=0.001, score=-0.07676712867998403, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV] .. C=0.01, gamma=0.001, score=-0.05567238006767638, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV] . C=0.01, gamma=0.001, score=0.0023182665048997464, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV]  C=0.01, gamma=0.001, score=-0.0008077783830460206, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] .... C=0.01, gamma=0.01, score=0.01752721556798076, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] .. C=0.01, gamma=0.01, score=-0.051179720572115395, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] .. C=0.01, gamma=0.01, score=-0.034772200346262494, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] ... C=0.01, gamma=0.01, score=0.028162349577888768, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] ... C=0.01, gamma=0.01, score=0.028872090432157105, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ..... C=0.01, gamma=0.1, score=0.12461864298606308, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ..... C=0.01, gamma=0.1, score=0.04381432618798209, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ..... C=0.01, gamma=0.1, score=0.06726586345931118, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ..... C=0.01, gamma=0.1, score=0.12557003105988251, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ...... C=0.01, gamma=0.1, score=0.1389987786840381, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ....... C=0.01, gamma=1, score=0.11076135714681556, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ...... C=0.01, gamma=1, score=0.041092304670148454, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ...... C=0.01, gamma=1, score=0.051083417325673786, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ....... C=0.01, gamma=1, score=0.11045873493977389, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ....... C=0.01, gamma=1, score=0.11637834361165722, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ... C=0.1, gamma=0.001, score=0.019929033079770897, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .. C=0.1, gamma=0.001, score=-0.049037690864073724, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .. C=0.1, gamma=0.001, score=-0.032667504804419156, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ... C=0.1, gamma=0.001, score=0.030848855357149544, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] .... C=0.1, gamma=0.001, score=0.03099786259632642, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..... C=0.1, gamma=0.01, score=0.22183956783130565, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..... C=0.1, gamma=0.01, score=0.13510375463586854, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ...... C=0.1, gamma=0.01, score=0.1635953058966464, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..... C=0.1, gamma=0.01, score=0.23211015873395738, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..... C=0.1, gamma=0.01, score=0.23493582221160894, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....... C=0.1, gamma=0.1, score=0.6382653390508292, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....... C=0.1, gamma=0.1, score=0.5059411665527334, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....... C=0.1, gamma=0.1, score=0.4751116942499939, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....... C=0.1, gamma=0.1, score=0.5385566150641292, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ....... C=0.1, gamma=0.1, score=0.5146337098525107, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......... C=0.1, gamma=1, score=0.6094658201026772, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] ......... C=0.1, gamma=1, score=0.4806547023324649, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......... C=0.1, gamma=1, score=0.4714936219267283, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......... C=0.1, gamma=1, score=0.4988347837011856, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] .......... C=0.1, gamma=1, score=0.507130273473452, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...... C=1, gamma=0.001, score=0.23480513099959713, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.1536795817506571, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...... C=1, gamma=0.001, score=0.18002760275926888, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ...... C=1, gamma=0.001, score=0.24467758658626618, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.2508480624200021, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.7101139133652017, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] .......... C=1, gamma=0.01, score=0.59111034327417, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.5655519081946162, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.5837141542369253, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ......... C=1, gamma=0.01, score=0.524728778621343, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] .......... C=1, gamma=0.1, score=0.818862728423727, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......... C=1, gamma=0.1, score=0.7399056958901755, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......... C=1, gamma=0.1, score=0.6284771378112209, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......... C=1, gamma=0.1, score=0.5899419540064671, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......... C=1, gamma=0.1, score=0.4676689646332693, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........... C=1, gamma=1, score=0.8511044637823257, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ............. C=1, gamma=1, score=0.79999042237016, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........... C=1, gamma=1, score=0.7087914968382111, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........... C=1, gamma=1, score=0.5701584596313964, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........... C=1, gamma=1, score=0.5687510873728114, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.6964488367795292, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.5927965467443461, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.5626603659234504, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.5759050371728212, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.5216236505089442, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.7511379532698841, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.6575470974014972, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.5941736846487933, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.5738994346747706, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ...... C=10, gamma=0.01, score=0.43229904668280866, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........ C=10, gamma=0.1, score=0.8295541623344345, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........ C=10, gamma=0.1, score=0.7555326146742588, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........ C=10, gamma=0.1, score=0.6353940730139764, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........ C=10, gamma=0.1, score=0.5769177799426308, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ....... C=10, gamma=0.1, score=0.42943719604517205, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.8549628803499406, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.8429462244270075, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.7943751060634678, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.6349704860306592, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.5971340054891533, total=   0.0s
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.4s finished
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=True),
#        error_score='raise-deprecating',
#        estimator=SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#   gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'C': [0.001, 0.01, 0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1, 1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %% [markdown]
# What ``fit`` does is a bit more involved then what we did above. First, it runs the same loop with cross-validation, to find the best parameter combination.
# Once it has the best combination, it runs fit again on all data passed to fit (without cross-validation), to built a single new model using the best parameter setting.

# %% [markdown]
# Then, as with all models, we can use ``predict`` or ``score``:

# %%
grid.predict(X)
# Out:
# array([-1.79762875, -1.74054091, -1.71412904, -1.72272347, -1.76880247,
#        -1.8527208 , -1.97255382, -2.12407501, -2.30087676, -2.49463429,
#        -2.695503  , -2.89262935, -3.07474705, -3.23082299, -3.35071314,
#        -3.42578612, -3.44947391, -3.41771237, -3.32924127, -3.18574205,
#        -2.9918017 , -2.75470244, -2.48404785, -2.19124658, -1.88888388,
#        -1.59001819, -1.30744475, -1.05297034, -0.8367425 , -0.66667333,
#        -0.54799235, -0.4829551 , -0.4707249 , -0.50743515, -0.58642852,
#        -0.69865919, -0.83323456, -0.97806438, -1.12057877, -1.24847261,
#        -1.35043139, -1.41679516, -1.44012026, -1.41560488, -1.3413525 ,
#        -1.21845724, -1.05090633, -0.84530623, -0.61045003, -0.35675398,
#        -0.09559933,  0.16137852,  0.40300817,  0.61926205,  0.80185531,
#         0.94472644,  1.04437082,  1.10000798,  1.11357463,  1.08954695,
#         1.03460678,  0.95717608,  0.86685224,  0.7737823 ,  0.68801751,
#         0.61888941,  0.57444669,  0.56098656,  0.58270777,  0.64150352,
#         0.73690334,  0.86616306,  1.02449275,  1.20540425,  1.40115266,
#         1.60324152,  1.80295801,  1.99190412,  2.16249073,  2.3083654 ,
#         2.42474939,  2.50866621,  2.55905134,  2.57674055,  2.56434191,
#         2.52600389,  2.46709789,  2.39383845,  2.31286721,  2.23082834,
#         2.15396216,  2.0877418 ,  2.03657355,  2.00357681,  1.99045342,
#         1.99745004,  2.02341108,  2.06591373,  2.12147209,  2.18579347])

# %% [markdown]
# You can inspect the best parameters found by ``GridSearchCV`` in the ``best_params_`` attribute, and the best score in the ``best_score_`` attribute:

# %%
print(grid.best_score_)
# Out:
# 0.7448777404720457

# %%
print(grid.best_params_)
# Out:
# {'C': 10, 'gamma': 1}

# %% [markdown]
# There is a problem with using this score for evaluation, however.
#
# You might be making what is called a multiple hypothesis testing error.
#
# If you try very many parameter settings, some of them will work better just by chance, and the score that you obtained might not reflect how your model would perform on new unseen data.
#
# Therefore, it is good to split off a separate test-set before performing grid-search.
#
# This pattern can be seen as a **training-validation-test** split, and is common in machine learning:

# %% [markdown]
# <img src="../images/grid_search_cross_validation.svg" width="60%">

# %% [markdown]
# We can do this very easily by splitting of some test data using ``train_test_split``, training ``GridSearchCV`` on the training set, and applying the ``score`` method to the test set:

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1, 1]}
cv = KFold(n_splits=10, shuffle=True)

grid = GridSearchCV(SVR(), param_grid=param_grid, cv=cv, iid=True)

grid.fit(X_train, y_train)
grid.score(X_test, y_test)
# Out:
# 0.7415468573756707

# %% [markdown]
# Some practitioners go for an easier scheme, splitting the data simply into three parts: _training, validation and testing_.
#
# This is a possible alternative if your training set is very large, or it is infeasible to train many models using cross-validation because training a model takes very long.
#
# You can do this with scikit-learn for example by splitting of a test-set and then applying GridSearchCV with ShuffleSplit cross-validation with a single iteration:

# %% [markdown]
# <img src="../images/train_validation_test2.svg" width="60%">

# %%
from sklearn.model_selection import train_test_split, ShuffleSplit

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10], 'gamma': [0.001, 0.01, 0.1, 1]}
single_split_cv = ShuffleSplit(n_splits=1)

grid = GridSearchCV(SVR(), param_grid=param_grid, cv=single_split_cv, verbose=3)

grid.fit(X_train, y_train)
grid.score(X_test, y_test)
# Out:
# Fitting 1 folds for each of 20 candidates, totalling 20 fits
# [CV] C=0.001, gamma=0.001 ............................................
# [CV]  C=0.001, gamma=0.001, score=-0.007521590153583445, total=   0.0s
# [CV] C=0.001, gamma=0.01 .............................................
# [CV] . C=0.001, gamma=0.01, score=-0.005732111479404445, total=   0.0s
# [CV] C=0.001, gamma=0.1 ..............................................
# [CV] .. C=0.001, gamma=0.1, score=0.0022098154436575035, total=   0.0s
# [CV] C=0.001, gamma=1 ................................................
# [CV] ..... C=0.001, gamma=1, score=0.001274644495456334, total=   0.0s
# [CV] C=0.01, gamma=0.001 .............................................
# [CV] . C=0.01, gamma=0.001, score=-0.005552472410777831, total=   0.0s
# [CV] C=0.01, gamma=0.01 ..............................................
# [CV] ... C=0.01, gamma=0.01, score=0.012188506218757778, total=   0.0s
# [CV] C=0.01, gamma=0.1 ...............................................
# [CV] ..... C=0.01, gamma=0.1, score=0.08437149536836663, total=   0.0s
# [CV] C=0.01, gamma=1 .................................................
# [CV] ....... C=0.01, gamma=1, score=0.07758148326702008, total=   0.0s
# [CV] C=0.1, gamma=0.001 ..............................................
# [CV] ... C=0.1, gamma=0.001, score=0.013951626740195568, total=   0.0s
# [CV] C=0.1, gamma=0.01 ...............................................
# [CV] ..... C=0.1, gamma=0.01, score=0.16595880066395685, total=   0.0s
# [CV] C=0.1, gamma=0.1 ................................................
# [CV] ...... C=0.1, gamma=0.1, score=0.49601294257591344, total=   0.0s
# [CV] C=0.1, gamma=1 ..................................................
# [CV] ......... C=0.1, gamma=1, score=0.4918334993576332, total=   0.0s
# [CV] C=1, gamma=0.001 ................................................
# [CV] ....... C=1, gamma=0.001, score=0.1798292672937536, total=   0.0s
# [CV] C=1, gamma=0.01 .................................................
# [CV] ........ C=1, gamma=0.01, score=0.6299963317777624, total=   0.0s
# [CV] C=1, gamma=0.1 ..................................................
# [CV] ......... C=1, gamma=0.1, score=0.7516890130224438, total=   0.0s
# [CV] C=1, gamma=1 ....................................................
# [CV] ........... C=1, gamma=1, score=0.7610891362786832, total=   0.0s
# [CV] C=10, gamma=0.001 ...............................................
# [CV] ...... C=10, gamma=0.001, score=0.6178086841063226, total=   0.0s
# [CV] C=10, gamma=0.01 ................................................
# [CV] ....... C=10, gamma=0.01, score=0.6926357479907056, total=   0.0s
# [CV] C=10, gamma=0.1 .................................................
# [CV] ........ C=10, gamma=0.1, score=0.7758451344124846, total=   0.0s
# [CV] C=10, gamma=1 ...................................................
# [CV] .......... C=10, gamma=1, score=0.8259219341432275, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.1s finished
# 0.7415468573756707

# %% [markdown]
# This is much faster, but will likely result worse hyperparameters and therefore worse results.

# %%
clf = GridSearchCV(SVR(), param_grid=param_grid, iid=True)
cross_val_score(clf, X, y)
# Out:
# /Users/valerio/anaconda3/envs/develer-science/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/valerio/anaconda3/envs/develer-science/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /Users/valerio/anaconda3/envs/develer-science/lib/python3.6/site-packages/sklearn/model_selection/_split.py:1943: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# array([0.04485824, 0.06299537, 0.04814317])
